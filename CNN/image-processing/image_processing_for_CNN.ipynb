# %% [markdown]
# Steps:
# - Reading an image file and converting it to a numpy array
#
# - Resizing an image
#
# - RGB to Grayscale conversio

# %%
# getting an image using web get
# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2025-02-11 10:36:53--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 3.170.73.117, 3.170.73.63, 3.170.73.80, ...
# Connecting to tractive.com (tractive.com)|3.170.73.117|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K   615KB/s    in 0.2s
#
# 2025-02-11 10:36:53 (615 KB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %% [markdown]
# Libraries to use for image processing:
#
# matplotlib.image
#
# Pillow
#
# OpenCV (cv2)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/dog.jpg')

# %%
# the image is now a numpy array

type(img)

print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %%
# Resizing the image using Pillow library

from PIL import Image

img = Image.open('/content/dog.jpg')
img_resized = img.resize((200, 200))

img_resized.save('dog_image_resized.jpg')

# displaying the image from numpy array

img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
# Converting RGB images to Grayscale image using OpenCV

import cv2

img = cv2.imread('/content/dog_image_resized.jpg')
print(type(img))
img.shape
# Out:
# <class 'numpy.ndarray'>
# (200, 200, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

grayscale_image.shape
# Out:
# (200, 200)

# %%
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
from google.colab.patches import cv2_imshow

# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
